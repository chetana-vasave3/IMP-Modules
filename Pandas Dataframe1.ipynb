# %% [markdown]
# .
#
#
#
#
#
#
#
#
# ### DataFrame

# %% [markdown]
# - Its a tabular data structure having rows and coloumn in 2 d format
# - Can pass(list,dict,series and dataframe) as an argument

# %%
import pandas as pd

empty_df=pd.DataFrame()

print(empty_df)

#empty Datafream
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Creating Dataframe from dict

# %%
my_dict={"cricketer":["VK","MS","ABD"],"name":[1000,5000,6000],"teams":["RBC","CSK","MI"]}
print(my_dict)
# Out:
# {'cricketer': ['VK', 'MS', 'ABD'], 'name': [1000, 5000, 6000], 'teams': ['RBC', 'CSK', 'MI']}

# %%
cric_df=pd.DataFrame(my_dict)
cric_df
# Out:
#   cricketer  name teams
# 0        VK  1000   RBC
# 1        MS  5000   CSK
# 2       ABD  6000    MI

# %% [markdown]
# ### Creating the dataframe from list tupples

# %%
list_tuple=[(1,2,9),(3,4,8),(5,6,10),(10,20)]
list_tuple
# Out:
# [(1, 2, 9), (3, 4, 8), (5, 6, 10), (10, 20)]

# %%
df_t=pd.DataFrame(list_tuple)
df_t
# Out:
#     0   1     2
# 0   1   2   9.0
# 1   3   4   8.0
# 2   5   6  10.0
# 3  10  20   NaN

# %% [markdown]
# #### Creating the dataframe from list

# %%
df_1=pd.DataFrame([[1,2,3],[2,3,4],[100,200,300]])
df_1
# Out:
#      0    1    2
# 0    1    2    3
# 1    2    3    4
# 2  100  200  300

# %% [markdown]
# ### Creating Dataframe from the csv file

# %%
df_csv=pd.read_csv(r"C:\Users\ipcs\Downloads\FitBit data.csv")

# %%
df_csv
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     8/4/2016       23014      20.389999        20.389999
# 453  8877689391     9/4/2016       16470       8.070000         8.070000
# 454  8877689391    10/4/2016       28497      27.530001        27.530001
# 455  8877689391    11/4/2016       10622       8.060000         8.060000
# 456  8877689391    12/4/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
import pandas as pd

# %%
df=pd.read_excel(r"C:\Users\ipcs\Downloads\weather_data.xls")#xlsx

# %%
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        7.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08         31.0        2.0   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %% [markdown]
# #### 1.Shape

# %%
df.shape  #(rows,column)
# Out:
# (9, 4)

# %% [markdown]
# #### 2.Value_counts()

# %%
df.value_counts("temperature")
# Out:
# temperature
# 32.0    2
# 28.0    1
# 31.0    1
# 34.0    1
# 40.0    1
# dtype: int64

# %%
df.value_counts("event")
# Out:
# event
# Sunny     3
# Rain      2
# Cloudy    1
# Snow      1
# dtype: int64

# %% [markdown]
# #### 3.sort_values()

# %%
df.sort_values("event",ascending=False)  #by default ascending=True
# Out:
#          day  temperature  windspeed   event
# 1 2017-01-04          NaN        7.0   Sunny
# 5 2017-01-08         31.0        2.0   Sunny
# 8 2017-01-11         40.0       12.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 0 2017-01-01         32.0        6.0    Rain
# 4 2017-01-07         32.0        NaN    Rain
# 7 2017-01-10         34.0        8.0  Cloudy
# 3 2017-01-06          NaN        7.0     NaN
# 6 2017-01-09          NaN        NaN     NaN

# %%
df.sort_values("temperature",ascending=False)
# Out:
#          day  temperature  windspeed   event
# 8 2017-01-11         40.0       12.0   Sunny
# 7 2017-01-10         34.0        8.0  Cloudy
# 0 2017-01-01         32.0        6.0    Rain
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08         31.0        2.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 1 2017-01-04          NaN        7.0   Sunny
# 3 2017-01-06          NaN        7.0     NaN
# 6 2017-01-09          NaN        NaN     NaN

# %% [markdown]
# #### 4.head()

# %%
df.head()
# Out:
#          day  temperature  windspeed  event
# 0 2017-01-01         32.0        6.0   Rain
# 1 2017-01-04          NaN        7.0  Sunny
# 2 2017-01-05         28.0        NaN   Snow
# 3 2017-01-06          NaN        7.0    NaN
# 4 2017-01-07         32.0        NaN   Rain

# %%
df.head(6)
# Out:
#          day  temperature  windspeed  event
# 0 2017-01-01         32.0        6.0   Rain
# 1 2017-01-04          NaN        7.0  Sunny
# 2 2017-01-05         28.0        NaN   Snow
# 3 2017-01-06          NaN        7.0    NaN
# 4 2017-01-07         32.0        NaN   Rain
# 5 2017-01-08         31.0        2.0  Sunny

# %% [markdown]
# #### 5.tail()

# %%
df.tail()
# Out:
#          day  temperature  windspeed   event
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08         31.0        2.0   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %% [markdown]
# #### 6.index

# %%
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        7.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08         31.0        2.0   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
df2=pd.DataFrame(df)

# %%
df2
# Out:
#          day  temperature  windspeed   event
# 1 2017-01-04          NaN        7.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08         31.0        2.0   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
df2=pd.DataFrame(df)
df2
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        7.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08         31.0        2.0   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %% [markdown]
# #### 7.loc()

# %%
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        7.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08         31.0        2.0   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
df.loc[0:4,"temperature":"windspeed"]       #loc[row_name,column_name]
# Out:
#    temperature  windspeed
# 0         32.0        6.0
# 1          NaN        7.0
# 2         28.0        NaN
# 3          NaN        7.0
# 4         32.0        NaN

# %% [markdown]
# #### 8.iloc

# %%
df.iloc[0:4,2:]   #iloc[row_index,column_index]
# Out:
#    windspeed  event
# 0        6.0   Rain
# 1        7.0  Sunny
# 2        NaN   Snow
# 3        7.0    NaN

# %%
df=pd.read_csv(r"C:\Users\ipcs\Downloads\Placement.csv")#csv

# %%
df
# Out:
#          name of company                                  college name  \
# 0                XORIANT               XAVIER INSTITUTE OF ENGINEERING
# 1                XORIANT  INDIRA COLLEGE OF ENGINEERING AND MANAGEMENT
# 2                XORIANT           VISHWAKARMA INSTITUTE OF TECHNOLOGY
# 3                QUINNOX                 PILLAI COLLEGE OF ENGINEERING
# 4                QUINNOX  THAKUR COLLEGE OF ENGINEERING AND TECHNOLOGY
# ..                   ...                                           ...
# 457  ARK TECHNOSOLUTIONS  THAKUR COLLEGE OF ENGINEERING AND TECHNOLOGY
# 458             ACCOLITE          K. J. SOMAIYA COLLEGE OF ENGINEERING
# 459             ACCOLITE         PUNE INSTITUTE OF COMPUTER TECHNOLOGY
# 460             ACCOLITE         PUNE INSTITUTE OF COMPUTER TECHNOLOGY
# 461             ACCOLITE         PUNE INSTITUTE OF COMPUTER TECHNOLOGY
#
#           region  year   Salary
# 0         MUMBAI  2018   657673
# 1           PUNE  2018   657673
# ...

# %%
df.loc[3:3,"region":"region"]
# Out:
#         region
# 3  NAVI MUMBAI

# %%
df.iloc[3:4,2:3]
# Out:
#         region
# 3  NAVI MUMBAI

# %%
df.loc[0:3,"name of company":"college name"]
# Out:
#   name of company                                  college name
# 0         XORIANT               XAVIER INSTITUTE OF ENGINEERING
# 1         XORIANT  INDIRA COLLEGE OF ENGINEERING AND MANAGEMENT
# 2         XORIANT           VISHWAKARMA INSTITUTE OF TECHNOLOGY
# 3         QUINNOX                 PILLAI COLLEGE OF ENGINEERING

# %%
df.iloc[0:4,0:2]
# Out:
#   name of company                                  college name
# 0         XORIANT               XAVIER INSTITUTE OF ENGINEERING
# 1         XORIANT  INDIRA COLLEGE OF ENGINEERING AND MANAGEMENT
# 2         XORIANT           VISHWAKARMA INSTITUTE OF TECHNOLOGY
# 3         QUINNOX                 PILLAI COLLEGE OF ENGINEERING

# %%
import json

# %%
open(r"C:\Users\ipcs nagpur\Downloads\data.json","r")
# Out:
# <_io.TextIOWrapper name='C:\\Users\\ipcs nagpur\\Downloads\\data.json' mode='r' encoding='cp1252'>

# %%
json_file=pd.read_json(r"C:\Users\ipcs nagpur\Downloads\data.json")

# %%
json_file
# Out:
#                                          emp_details
# 0  {'emp_name': 'Sayli', 'email': 'sayali123@gmai...
# 1  {'emp_name': 'prachi', 'email': 'prachi123@gma...
# 2  {'emp_name': 'Gauri', 'email': 'Gauri123@gmail...

# %%
json_file.to_string()
# Out:
# "                                                                              emp_details\n0  {'emp_name': 'Sayli', 'email': 'sayali123@gmail.com', 'job_prtofile': 'data scintist'}\n1   {'emp_name': 'prachi', 'email': 'prachi123@gmail.com', 'job_prtofile': 'dataanalyst'}\n2     {'emp_name': 'Gauri', 'email': 'Gauri123@gmail.com', 'job_prtofile': 'It Engineer'}"

# %%
df=pd.read_excel(r"C:\Users\ipcs\Downloads\weather_data.xls")#xlsx

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          9 non-null      datetime64[ns]
#  1   temperature  6 non-null      float64
#  2   windspeed    6 non-null      float64
#  3   event        7 non-null      object
# dtypes: datetime64[ns](1), float64(2), object(1)
# memory usage: 420.0+ bytes

# %%
df.describe()
# Out:
#        temperature  windspeed
# count     6.000000   6.000000
# mean     32.833333   7.000000
# std       4.020779   3.224903
# min      28.000000   2.000000
# 25%      31.250000   6.250000
# 50%      32.000000   7.000000
# 75%      33.500000   7.750000
# max      40.000000  12.000000

# %% [markdown]
# ### Handle Missing Values

# %% [markdown]
# #### isnull()

# %%
df.isnull()
# Out:
#      day  temperature  windspeed  event
# 0  False        False      False  False
# 1  False         True      False  False
# 2  False        False       True  False
# 3  False         True      False   True
# 4  False        False       True  False
# 5  False        False      False  False
# 6  False         True       True   True
# 7  False        False      False  False
# 8  False        False      False  False

# %%
df.isnull().sum()  #add nan files
# Out:
# day            0
# temperature    3
# windspeed      3
# event          2
# dtype: int64

# %%
import missingno  # To visualize missing values
missingno.heatmap(df)
# Out:
# <Axes: >

# %% [markdown]
# ### To check duplicates

# %%
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        7.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08         31.0        2.0   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %% [markdown]
# #### duplicated

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.duplicated("event")
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5     True
# 6     True
# 7    False
# 8     True
# dtype: bool

# %%
df.duplicated("event").sum()
# Out:
# 4

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### fillna()

# %%
df.isnull().sum()
# Out:
# day            0
# temperature    3
# windspeed      3
# event          2
# dtype: int64

# %%
df["temperature"].fillna(df["temperature"].mean(),inplace=True)

# %%
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01    32.000000        6.0    Rain
# 1 2017-01-04    32.833333        7.0   Sunny
# 2 2017-01-05    28.000000        NaN    Snow
# 3 2017-01-06    32.833333        7.0     NaN
# 4 2017-01-07    32.000000        NaN    Rain
# 5 2017-01-08    31.000000        2.0   Sunny
# 6 2017-01-09    32.833333        NaN     NaN
# 7 2017-01-10    34.000000        8.0  Cloudy
# 8 2017-01-11    40.000000       12.0   Sunny

# %%
df2=df.fillna(df["windspeed"].mean())
df2
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01    32.000000        6.0    Rain
# 1 2017-01-04    32.833333        7.0   Sunny
# 2 2017-01-05    28.000000        7.0    Snow
# 3 2017-01-06    32.833333        7.0     7.0
# 4 2017-01-07    32.000000        7.0    Rain
# 5 2017-01-08    31.000000        2.0   Sunny
# 6 2017-01-09    32.833333        7.0     7.0
# 7 2017-01-10    34.000000        8.0  Cloudy
# 8 2017-01-11    40.000000       12.0   Sunny

# %%
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01    32.000000        6.0    Rain
# 1 2017-01-04    32.833333        7.0   Sunny
# 2 2017-01-05    28.000000        NaN    Snow
# 3 2017-01-06    32.833333        7.0     NaN
# 4 2017-01-07    32.000000        NaN    Rain
# 5 2017-01-08    31.000000        2.0   Sunny
# 6 2017-01-09    32.833333        NaN     NaN
# 7 2017-01-10    34.000000        8.0  Cloudy
# 8 2017-01-11    40.000000       12.0   Sunny

# %%
df["event"].fillna("no event",inplace=True)

# %%
df.fillna(df["event"].mode()[0])
# Out:
#          day temperature windspeed     event
# 0 2017-01-01        32.0       6.0      Rain
# 1 2017-01-04       Sunny       7.0     Sunny
# 2 2017-01-05        28.0     Sunny      Snow
# 3 2017-01-06       Sunny       7.0  no event
# 4 2017-01-07        32.0     Sunny      Rain
# 5 2017-01-08        31.0       2.0     Sunny
# 6 2017-01-09       Sunny     Sunny  no event
# 7 2017-01-10        34.0       8.0    Cloudy
# 8 2017-01-11        40.0      12.0     Sunny

# %%
df.fillna(df["temperature"].mean())
# Out:
#          day  temperature  windspeed     event
# 0 2017-01-01    32.000000   6.000000      Rain
# 1 2017-01-04    32.833333   7.000000     Sunny
# 2 2017-01-05    28.000000  32.833333      Snow
# 3 2017-01-06    32.833333   7.000000  no event
# 4 2017-01-07    32.000000  32.833333      Rain
# 5 2017-01-08    31.000000   2.000000     Sunny
# 6 2017-01-09    32.833333  32.833333  no event
# 7 2017-01-10    34.000000   8.000000    Cloudy
# 8 2017-01-11    40.000000  12.000000     Sunny

# %%
l=pd.DataFrame([1,1,1,1,2,2,2,33,4,4,5,1,1])
l
#mode=1
# Out:
#      0
# 0    1
# 1    1
# 2    1
# 3    1
# 4    2
# 5    2
# 6    2
# 7   33
# 8    4
# 9    4
# 10   5
# 11   1
# 12   1

# %%
l.mode()
# Out:
#    0
# 0  1

# %%
l.mode()[0]
# Out:
# 0    1
# Name: 0, dtype: int64

# %%
df
# Out:
#          day  temperature  windspeed     event
# 0 2017-01-01         32.0        6.0      Rain
# 1 2017-01-04          NaN        7.0     Sunny
# 2 2017-01-05         28.0        NaN      Snow
# 3 2017-01-06          NaN        7.0  no event
# 4 2017-01-07         32.0        NaN      Rain
# 5 2017-01-08         31.0        2.0     Sunny
# 6 2017-01-09          NaN        NaN  no event
# 7 2017-01-10         34.0        8.0    Cloudy
# 8 2017-01-11         40.0       12.0     Sunny

# %%
df["event"].fillna(df["event"].mode()[0])
# Out:
# 0      Rain
# 1     Sunny
# 2      Snow
# 3     Sunny
# 4      Rain
# 5     Sunny
# 6     Sunny
# 7    Cloudy
# 8     Sunny
# Name: event, dtype: object

# %%
df
# Out:
#          day  temperature  windspeed     event
# 0 2017-01-01    32.000000        6.0      Rain
# 1 2017-01-04    32.833333        7.0     Sunny
# 2 2017-01-05    28.000000        NaN      Snow
# 3 2017-01-06    32.833333        7.0  no event
# 4 2017-01-07    32.000000        NaN      Rain
# 5 2017-01-08    31.000000        2.0     Sunny
# 6 2017-01-09    32.833333        NaN  no event
# 7 2017-01-10    34.000000        8.0    Cloudy
# 8 2017-01-11    40.000000       12.0     Sunny

# %%
df["windspeed"].fillna(df["windspeed"].mode()[0],inplace=True)

# %%
df
# Out:
#          day  temperature  windspeed     event
# 0 2017-01-01    32.000000        6.0      Rain
# 1 2017-01-04    32.833333        7.0     Sunny
# 2 2017-01-05    28.000000        7.0      Snow
# 3 2017-01-06    32.833333        7.0  no event
# 4 2017-01-07    32.000000        7.0      Rain
# 5 2017-01-08    31.000000        2.0     Sunny
# 6 2017-01-09    32.833333        7.0  no event
# 7 2017-01-10    34.000000        8.0    Cloudy
# 8 2017-01-11    40.000000       12.0     Sunny

# %%
df["event"].fillna(df["event"].mode()[0],inplace=True)

# %%
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01    32.000000        6.0    Rain
# 1 2017-01-04    32.833333        7.0   Sunny
# 2 2017-01-05    28.000000        NaN    Snow
# 3 2017-01-06    32.833333        7.0   Sunny
# 4 2017-01-07    32.000000        NaN    Rain
# 5 2017-01-08    31.000000        2.0   Sunny
# 6 2017-01-09    32.833333        NaN   Sunny
# 7 2017-01-10    34.000000        8.0  Cloudy
# 8 2017-01-11    40.000000       12.0   Sunny

# %%
df["windspeed"].fillna(df["windspeed"].median(),inplace=True)

# %%
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01    32.000000        6.0    Rain
# 1 2017-01-04    32.833333        7.0   Sunny
# 2 2017-01-05    28.000000        7.0    Snow
# 3 2017-01-06    32.833333        7.0   Sunny
# 4 2017-01-07    32.000000        7.0    Rain
# 5 2017-01-08    31.000000        2.0   Sunny
# 6 2017-01-09    32.833333        7.0   Sunny
# 7 2017-01-10    34.000000        8.0  Cloudy
# 8 2017-01-11    40.000000       12.0   Sunny

# %% [markdown]
# #### dropna()

# %%
#It will delete the rows with nan

# %%
whether_data=pd.read_excel(r"C:\Users\ipcs\Downloads\weather_data.xls")

# %%
whether_data
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        7.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08         31.0        2.0   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
whether_data.dropna(inplace=True)   # all null values in rows and column

# %%
whether_data
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 5 2017-01-08         31.0        2.0   Sunny
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %% [markdown]
# # correlation function()

# %%
#It will find relation between two columns
#ranges from -1 to +1

# %% [markdown]
# #### corr() Applyies only on numerical columns

# %%
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        7.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08         31.0        2.0   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
df.corr()
# Out:
# C:\Users\ipcs\AppData\Local\Temp\ipykernel_5928\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#              temperature  windspeed
# temperature     1.000000   0.933488
# windspeed       0.933488   1.000000

# %%
#correlation() -1 to +1

# %%
bigmart_data=pd.read_csv(r"C:\Users\ipcs\Downloads\bigmart_data.csv")#csv

# %%
bigmart_data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38          NaN          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# ...

# %%
bigmart_data.corr()
# Out:
# C:\Users\ipcs\AppData\Local\Temp\ipykernel_5928\1497365578.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   bigmart_data.corr()
#                            Item_Weight  Item_Visibility  Item_MRP  \
# Item_Weight                   1.000000        -0.019089  0.049809
# Item_Visibility              -0.019089         1.000000 -0.014013
# Item_MRP                      0.049809        -0.014013  1.000000
# Outlet_Establishment_Year     0.018918        -0.097040 -0.007233
#
#                            Outlet_Establishment_Year
# Item_Weight                                 0.018918
# Item_Visibility                            -0.097040
# Item_MRP                                   -0.007233
# Outlet_Establishment_Year                   1.000000

# %%
iris=pd.read_csv(r"C:\Users\ipcs\Downloads\iris_csv.csv")

# %%
iris
# Out:
#      sepallength  sepalwidth  petallength  petalwidth           class
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.corr()
# Out:
# C:\Users\ipcs\AppData\Local\Temp\ipykernel_5928\2141086772.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   iris.corr()
#              sepallength  sepalwidth  petallength  petalwidth
# sepallength     1.000000   -0.109369     0.871754    0.817954
# sepalwidth     -0.109369    1.000000    -0.420516   -0.356544
# petallength     0.871754   -0.420516     1.000000    0.962757
# petalwidth      0.817954   -0.356544     0.962757    1.000000

# %% [markdown]
# ### dtypes

# %%
import pandas as pd

# %%
df_csv=pd.read_csv(r"C:\Users\ipcs\Downloads\FitBit data.csv")
df_csv
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     8/4/2016       23014      20.389999        20.389999
# 453  8877689391     9/4/2016       16470       8.070000         8.070000
# 454  8877689391    10/4/2016       28497      27.530001        27.530001
# 455  8877689391    11/4/2016       10622       8.060000         8.060000
# 456  8877689391    12/4/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
df_csv.dtypes
# Out:
# Id                            int64
# ActivityDate                  int64
# TotalSteps                    int64
# TotalDistance               float64
# TrackerDistance             float64
# LoggedActivitiesDistance    float64
# VeryActiveDistance          float64
# ModeratelyActiveDistance    float64
# LightActiveDistance         float64
# SedentaryActiveDistance     float64
# VeryActiveMinutes             int64
# FairlyActiveMinutes           int64
# LightlyActiveMinutes          int64
# SedentaryMinutes              int64
# Calories                      int64
# dtype: object

# %% [markdown]
# #### info()

# %%
df_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        457 non-null    int64
#  1   ActivityDate              457 non-null    object
#  2   TotalSteps                457 non-null    int64
#  3   TotalDistance             457 non-null    float64
#  4   TrackerDistance           457 non-null    float64
#  5   LoggedActivitiesDistance  457 non-null    float64
#  6   VeryActiveDistance        457 non-null    float64
#  7   ModeratelyActiveDistance  457 non-null    float64
#  8   LightActiveDistance       457 non-null    float64
#  9   SedentaryActiveDistance   457 non-null    float64
#  10  VeryActiveMinutes         457 non-null    int64
#  11  FairlyActiveMinutes       457 non-null    int64
#  12  LightlyActiveMinutes      457 non-null    int64
# ...

# %% [markdown]
# #### describe()

# %%
#it will statuistically describe the columns

# %%
df_csv.describe()
# Out:
#                  Id  ActivityDate    TotalSteps  TotalDistance  \
# count  4.570000e+02    457.000000    457.000000     457.000000
# mean   4.628595e+09  42518.741794   6546.562363       4.663523
# std    2.293781e+09     98.357002   5398.493064       4.082072
# min    1.503960e+09  42373.000000      0.000000       0.000000
# 25%    2.347168e+09  42447.000000   1988.000000       1.410000
# 50%    4.057193e+09  42494.000000   5986.000000       4.090000
# 75%    6.391747e+09  42586.000000  10198.000000       7.160000
# max    8.877689e+09  42708.000000  28497.000000      27.530001
#
#        TrackerDistance  LoggedActivitiesDistance  VeryActiveDistance  \
# count       457.000000                457.000000          457.000000
# mean          4.609847                  0.179427            1.180897
# std           4.068540                  0.849232            2.487159
# min           0.000000                  0.000000            0.000000
# ...

# %%
import pandas as pd

# %%
data=pd.DataFrame({'Brand':['Maruti','Hyundai','Tata',
                 'Mahindra','Maruti','Hyundai',
                 'Renault','Tata','Maruti'],
                   'Year':[2012,2014,2011,2015,2012,
                           2016,2014,2018,2019],
                   'Kms Driven':[5000,3000,6000,
                          25000,1000,46000,3100,1500,1200],
                   'City':['Gurgaon','Dehli','Mumbai',
                   'Dehli','Mumbai','Dehli',
                   'Mumbai','Chennai','Gaziabad'],
                   'Mileage':[28,27,25,26,28,29,
                      24,21,24]})

# %%
data
# Out:
#       Brand  Year  Kms Driven      City  Mileage
# 0    Maruti  2012        5000   Gurgaon       28
# 1   Hyundai  2014        3000     Dehli       27
# 2      Tata  2011        6000    Mumbai       25
# 3  Mahindra  2015       25000     Dehli       26
# 4    Maruti  2012        1000    Mumbai       28
# 5   Hyundai  2016       46000     Dehli       29
# 6   Renault  2014        3100    Mumbai       24
# 7      Tata  2018        1500   Chennai       21
# 8    Maruti  2019        1200  Gaziabad       24

# %% [markdown]
# - Note:- Last value is exclsive in iloc which means not include

# %%
data.head(5)
# Out:
#       Brand  Year  Kms Driven     City  Mileage
# 0    Maruti  2012        5000  Gurgaon       28
# 1   Hyundai  2014        3000    Dehli       27
# 2      Tata  2011        6000   Mumbai       25
# 3  Mahindra  2015       25000    Dehli       26
# 4    Maruti  2012        1000   Mumbai       28

# %% [markdown]
# #### [rows,cols]

# %%
data.loc[1,"Brand"]
# Out:
# 'Hyundai'

# %%
data.loc[0:2,"Brand":"Mileage"]
# Out:
#      Brand  Year  Kms Driven     City  Mileage
# 0   Maruti  2012        5000  Gurgaon       28
# 1  Hyundai  2014        3000    Dehli       27
# 2     Tata  2011        6000   Mumbai       25

# %%
data.iloc[0:3,:]
# Out:
#      Brand  Year  Kms Driven     City  Mileage
# 0   Maruti  2012        5000  Gurgaon       28
# 1  Hyundai  2014        3000    Dehli       27
# 2     Tata  2011        6000   Mumbai       25

# %%
data.iloc[0:3,0:2]
# Out:
#      Brand  Year
# 0   Maruti  2012
# 1  Hyundai  2014
# 2     Tata  2011

# %%
data.iloc[1:2,0:1]
# Out:
#      Brand
# 1  Hyundai

# %%
data
# Out:
#       Brand  Year  Kms Driven      City  Mileage
# 0    Maruti  2012        5000   Gurgaon       28
# 1   Hyundai  2014        3000     Dehli       27
# 2      Tata  2011        6000    Mumbai       25
# 3  Mahindra  2015       25000     Dehli       26
# 4    Maruti  2012        1000    Mumbai       28
# 5   Hyundai  2016       46000     Dehli       29
# 6   Renault  2014        3100    Mumbai       24
# 7      Tata  2018        1500   Chennai       21
# 8    Maruti  2019        1200  Gaziabad       24

# %%
data.sort_values("Mileage",ascending=False).iloc[0:1,:]
# Out:
#      Brand  Year  Kms Driven   City  Mileage
# 5  Hyundai  2016       46000  Dehli       29

# %%
data.loc[0:8,"Brand":"Year"]
# Out:
#       Brand  Year
# 0    Maruti  2012
# 1   Hyundai  2014
# 2      Tata  2011
# 3  Mahindra  2015
# 4    Maruti  2012
# 5   Hyundai  2016
# 6   Renault  2014
# 7      Tata  2018
# 8    Maruti  2019

# %%
data.iloc[7:1:-1,0:2]
# Out:
#       Brand  Year
# 7      Tata  2018
# 6   Renault  2014
# 5   Hyundai  2016
# 4    Maruti  2012
# 3  Mahindra  2015
# 2      Tata  2011

# %%
details={
     'Name':['Ankit','Aishwarya','Shaurya','shivangi'],
     'Age' :[23,21,23,21],
     'University' :['BHU','JNU','DU','BHU'],
}
data=pd.DataFrame(details,index=[4,3,2,1])

# %%
data
# Out:
#         Name  Age University
# 4      Ankit   23        BHU
# 3  Aishwarya   21        JNU
# 2    Shaurya   23         DU
# 1   shivangi   21        BHU

# %%
data.loc[3:2,:]
# Out:
#         Name  Age University
# 3  Aishwarya   21        JNU
# 2    Shaurya   23         DU

# %%
data.iloc[1:3,:]
# Out:
#         Name  Age University
# 3  Aishwarya   21        JNU
# 2    Shaurya   23         DU

# %%
details={
    'Name':['Ankit','Aishwarya','Shaurya','Shivangi'],
    'Age' :[23,21,22,21],
    'Univarsity':['BHU','JNU','DU','BHU'],
}
data1=pd.DataFrame(details,index=["a","b","c","d"])

# %%
data1
# Out:
#         Name  Age Univarsity
# a      Ankit   23        BHU
# b  Aishwarya   21        JNU
# c    Shaurya   22         DU
# d   Shivangi   21        BHU

# %%
data1.loc["b":"c",:]
# Out:
#         Name  Age Univarsity
# b  Aishwarya   21        JNU
# c    Shaurya   22         DU

# %%
data1.loc["b",:]
# Out:
# Name          Aishwarya
# Age                  21
# Univarsity          JNU
# Name: b, dtype: object

# %%
data1
# Out:
#         Name  Age Univarsity
# a      Ankit   23        BHU
# b  Aishwarya   21        JNU
# c    Shaurya   22         DU
# d   Shivangi   21        BHU

# %%
data1.iloc[3,:]
# Out:
# Name          Shivangi
# Age                 21
# Univarsity         BHU
# Name: d, dtype: object

# %%
car=pd.DataFrame({'Brand':['Maruti','Hyundai','Tata',
                 'Mahindra','Maruti','Hyundai',
                 'Renault','Tata','Maruti'],
                   'Year':[2012,2014,2011,2015,2012,
                           2016,2014,2018,2019],
                   'Kms Driven':[50000,30000,60000,
                          25000,10000,46000,31000,15000,12000],
                   'City':['Gurgaon','Dehli','Mumbai',
                   'Dehli','Mumbai','Dehli',
                   'Mumbai','Chennai','Gaziabad'],
                   'Mileage':[28,27,25,26,28,29,
                      24,21,24]})

# %%
car
# Out:
#       Brand  Year  Kms Driven      City  Mileage
# 0    Maruti  2012       50000   Gurgaon       28
# 1   Hyundai  2014       30000     Dehli       27
# 2      Tata  2011       60000    Mumbai       25
# 3  Mahindra  2015       25000     Dehli       26
# 4    Maruti  2012       10000    Mumbai       28
# 5   Hyundai  2016       46000     Dehli       29
# 6   Renault  2014       31000    Mumbai       24
# 7      Tata  2018       15000   Chennai       21
# 8    Maruti  2019       12000  Gaziabad       24

# %%
car["Mileage"]>=25
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6    False
# 7    False
# 8    False
# Name: Mileage, dtype: bool

# %%
type(car["Mileage"]>=25)
# Out:
# pandas.core.series.Series

# %%
car["Mileage"]>=25
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6    False
# 7    False
# 8    False
# Name: Mileage, dtype: bool

# %%
car
# Out:
#       Brand  Year  Kms Driven      City  Mileage
# 0    Maruti  2012       50000   Gurgaon       28
# 1   Hyundai  2014       30000     Dehli       27
# 2      Tata  2011       60000    Mumbai       25
# 3  Mahindra  2015       25000     Dehli       26
# 4    Maruti  2012       10000    Mumbai       28
# 5   Hyundai  2016       46000     Dehli       29
# 6   Renault  2014       31000    Mumbai       24
# 7      Tata  2018       15000   Chennai       21
# 8    Maruti  2019       12000  Gaziabad       24

# %%
car[(car["Mileage"]>=25)& (car["Year"]==2014)]
# Out:
#      Brand  Year  Kms Driven   City  Mileage
# 1  Hyundai  2014       30000  Dehli       27

# %%
car.loc[(car["Mileage"]>=25)& (car["Year"]==2014)]
# Out:
#      Brand  Year  Kms Driven   City  Mileage
# 1  Hyundai  2014       30000  Dehli       27

# %%
car[(car["Mileage"]>=25) & (car["Mileage"]<=27)]
# Out:
#       Brand  Year  Kms Driven    City  Mileage
# 1   Hyundai  2014       30000   Dehli       27
# 2      Tata  2011       60000  Mumbai       25
# 3  Mahindra  2015       25000   Dehli       26

# %%
car.iloc[(car["Mileage"]>=25) & (car["Mileage"]<=27)]
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 car.iloc[(car["Mileage"]>=25) & (car["Mileage"]<=27)]
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexing.py:1611, in _iLocIndexer._getitem_axis(self, key, axis)
#    1608     key = np.asarray(key)
#    1610 if com.is_bool_indexer(key):
# -> 1611     self._validate_key(key, axis)
#    1612     return self._getbool_axis(key, axis=axis)
#    1614 # a list of integers
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexing.py:1452, in _iLocIndexer._validate_key(self, key, axis)
# ...

# %%
car.iloc[list((car["Mileage"]>=25) & (car["Mileage"]<=27))]
# Out:
#       Brand  Year  Kms Driven    City  Mileage
# 1   Hyundai  2014       30000   Dehli       27
# 2      Tata  2011       60000  Mumbai       25
# 3  Mahindra  2015       25000   Dehli       26

# %%
car
# Out:
#       Brand  Year  Kms Driven      City  Mileage
# 0    Maruti  2012       50000   Gurgaon       28
# 1   Hyundai  2014       30000     Dehli       27
# 2      Tata  2011       60000    Mumbai       25
# 3  Mahindra  2015       25000     Dehli       26
# 4    Maruti  2012       10000    Mumbai       28
# 5   Hyundai  2016       46000     Dehli       29
# 6   Renault  2014       31000    Mumbai       24
# 7      Tata  2018       15000   Chennai       21
# 8    Maruti  2019       12000  Gaziabad       24

# %%
car.loc[car["Kms Driven"]>30000]
# Out:
#      Brand  Year  Kms Driven     City  Mileage
# 0   Maruti  2012       50000  Gurgaon       28
# 2     Tata  2011       60000   Mumbai       25
# 5  Hyundai  2016       46000    Dehli       29
# 6  Renault  2014       31000   Mumbai       24

# %% [markdown]
# #### To add the columns to existing dataframe

# %%
car["test"]=0

# %%
car
# Out:
#       Brand  Year  Kms Driven      City  Mileage  test
# 0    Maruti  2012       50000   Gurgaon       28     0
# 1   Hyundai  2014       30000     Dehli       27     0
# 2      Tata  2011       60000    Mumbai       25     0
# 3  Mahindra  2015       25000     Dehli       26     0
# 4    Maruti  2012       10000    Mumbai       28     0
# 5   Hyundai  2016       46000     Dehli       29     0
# 6   Renault  2014       31000    Mumbai       24     0
# 7      Tata  2018       15000   Chennai       21     0
# 8    Maruti  2019       12000  Gaziabad       24     0

# %%
car["test"]=car["Mileage"]*10

# %%
car
# Out:
#       Brand  Year  Kms Driven      City  Mileage  test
# 0    Maruti  2012       50000   Gurgaon       28   280
# 1   Hyundai  2014       30000     Dehli       27   270
# 2      Tata  2011       60000    Mumbai       25   250
# 3  Mahindra  2015       25000     Dehli       26   260
# 4    Maruti  2012       10000    Mumbai       28   280
# 5   Hyundai  2016       46000     Dehli       29   290
# 6   Renault  2014       31000    Mumbai       24   240
# 7      Tata  2018       15000   Chennai       21   210
# 8    Maruti  2019       12000  Gaziabad       24   240

# %% [markdown]
# #### Conditional Changes

# %%
import pandas as pd

# %%
details= {
    'Name': ['Ankit','Aishhwarya','Ankit','Aishwarya','Shaurya','Shivangi'],
    'Maths': [80,40,50,70,42,61],
    'Sci' : [83,21,43,61,72,71],
    'Hindi' : [53,21,73,11,92,11],
    'Chem': [73,41,43,41,82,91],
    'Bio' : [93,41,23,41,45,51],
    'Sanskrit': [73,81,53,41,72,21]
}
d1=pd.DataFrame(details)
d1
# Out:
#          Name  Maths  Sci  Hindi  Chem  Bio  Sanskrit
# 0       Ankit     80   83     53    73   93        73
# 1  Aishhwarya     40   21     21    41   41        81
# 2       Ankit     50   43     73    43   23        53
# 3   Aishwarya     70   61     11    41   41        41
# 4     Shaurya     42   72     92    82   45        72
# 5    Shivangi     61   71     11    91   51        21

# %%
d1["total"]=0

# %%
d1
# Out:
#          Name  Maths  Sci  Hindi  Chem  Bio  Sanskrit  total
# 0       Ankit     80   83     53    73   93        73      0
# 1  Aishhwarya     40   21     21    41   41        81      0
# 2       Ankit     50   43     73    43   23        53      0
# 3   Aishwarya     70   61     11    41   41        41      0
# 4     Shaurya     42   72     92    82   45        72      0
# 5    Shivangi     61   71     11    91   51        21      0

# %%
d1["total"]=d1["Maths"]+d1["Sci"]+d1["Hindi"]+d1["Chem"]+d1["Bio"]+d1["Sanskrit"]

# %%
d1
# Out:
#          Name  Maths  Sci  Hindi  Chem  Bio  Sanskrit  total
# 0       Ankit     80   83     53    73   93        73    455
# 1  Aishhwarya     40   21     21    41   41        81    245
# 2       Ankit     50   43     73    43   23        53    285
# 3   Aishwarya     70   61     11    41   41        41    265
# 4     Shaurya     42   72     92    82   45        72    405
# 5    Shivangi     61   71     11    91   51        21    306

# %%
d1["grade"]=0

# %%
d1
# Out:
#          Name  Maths  Sci  Hindi  Chem  Bio  Sanskrit  total  grade
# 0       Ankit     80   83     53    73   93        73    455      0
# 1  Aishhwarya     40   21     21    41   41        81    245      0
# 2       Ankit     50   43     73    43   23        53    285      0
# 3   Aishwarya     70   61     11    41   41        41    265      0
# 4     Shaurya     42   72     92    82   45        72    405      0
# 5    Shivangi     61   71     11    91   51        21    306      0

# %%
d1["%"]=(d1["total"]/600)*100

# %%
d1
# Out:
#          Name  Maths  Sci  Hindi  Chem  Bio  Sanskrit  total  grade          %
# 0       Ankit     80   83     53    73   93        73    455      0  75.833333
# 1  Aishhwarya     40   21     21    41   41        81    245      0  40.833333
# 2       Ankit     50   43     73    43   23        53    285      0  47.500000
# 3   Aishwarya     70   61     11    41   41        41    265      0  44.166667
# 4     Shaurya     42   72     92    82   45        72    405      0  67.500000
# 5    Shivangi     61   71     11    91   51        21    306      0  51.000000

# %% [markdown]
# - less than 45-Fail
# - 45-60 pass
# - 60-70 first class
# - 70- distinction

# %%
d1.loc[d1["%"]<45]
d1.loc[d1["%"]<45,"grade"]="FALL"

# %%
d1
# Out:
#          Name  Maths  Sci  Hindi  Chem  Bio  Sanskrit  total grade          %
# 0       Ankit     80   83     53    73   93        73    455     0  75.833333
# 1  Aishhwarya     40   21     21    41   41        81    245  FALL  40.833333
# 2       Ankit     50   43     73    43   23        53    285     0  47.500000
# 3   Aishwarya     70   61     11    41   41        41    265  FALL  44.166667
# 4     Shaurya     42   72     92    82   45        72    405     0  67.500000
# 5    Shivangi     61   71     11    91   51        21    306     0  51.000000

# %%
d1.loc[(d1["%"]>45) & (d1["%"]<60)]
d1.loc[(d1["%"]>45) & (d1["%"]<60),"grade"]="PASS"

# %%
(d1["%"]>45) & (d1["%"]<60)
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5     True
# Name: %, dtype: bool

# %%
d1
# Out:
#          Name  Maths  Sci  Hindi  Chem  Bio  Sanskrit  total grade          %
# 0       Ankit     80   83     53    73   93        73    455     0  75.833333
# 1  Aishhwarya     40   21     21    41   41        81    245  FALL  40.833333
# 2       Ankit     50   43     73    43   23        53    285  PASS  47.500000
# 3   Aishwarya     70   61     11    41   41        41    265  FALL  44.166667
# 4     Shaurya     42   72     92    82   45        72    405     0  67.500000
# 5    Shivangi     61   71     11    91   51        21    306  PASS  51.000000

# %%
d1.loc[(d1["%"]>70)]

d1.loc[(d1["%"]>70),"grade"]="DISTINCION"

d1.loc[(d1["%"]>60) & (d1["%"]<70)]

d1.loc[(d1["%"]>60) & (d1["%"]<70),"grade"]="FIRST CLASS"

# %%
d1
# Out:
#          Name  Maths  Sci  Hindi  Chem  Bio  Sanskrit  total
# 0       Ankit     80   83     53    73   93        73    455
# 1  Aishhwarya     40   21     21    41   41        81    245
# 2       Ankit     50   43     73    43   23        53    285
# 3   Aishwarya     70   61     11    41   41        41    265
# 4     Shaurya     42   72     92    82   45        72    405
# 5    Shivangi     61   71     11    91   51        21    306

# %%
len(d1.index)
# Out:
# 6
